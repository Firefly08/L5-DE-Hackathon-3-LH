# %%
import pandas as pd

# %%
edingburgh_columns = [
    'date', 
    'sunrise', 
    'sunset', 
    'daylength', 
    'moonrise', 
    'moonset', 
    'moonphase', 'moonillumination', 'moonage', 'moondistance', 'moonsign']

# %%
sheets = pd.read_excel('data/Edinburgh-daytime.xlsx', sheet_name=None)

all_sheets = []
for k in sheets.keys():
    all_sheets.append(sheets[k])
df = pd.concat(all_sheets, ignore_index=True)
df
# Out:
#     2011  Sunrise/Sunset      Unnamed: 2 Daylength  Unnamed: 4  \
# 0    Dec         Sunrise          Sunset    Length  Difference
# 1    NaN             NaN             NaN       NaN         NaN
# 2      1  08:18 ↑ (130°)  15:44 ↑ (230°)  07:25:45       −2:37
# 3      2  08:20 ↑ (130°)  15:43 ↑ (230°)  07:23:13       −2:31
# 4      3  08:21 ↑ (130°)  15:42 ↑ (229°)  07:20:48       −2:25
# ..   ...             ...             ...       ...         ...
# 485  NaN  08:16 ↑ (123°)  16:35 ↑ (237°)  08:19:28       +3:48
# 486  NaN  08:14 ↑ (122°)  16:37 ↑ (238°)  08:23:19       +3:51
# 487  NaN  08:12 ↑ (122°)  16:39 ↑ (238°)  08:27:14       +3:54
# 488  NaN  08:10 ↑ (121°)  16:42 ↑ (239°)  08:31:11       +3:57
# 489  NaN  08:08 ↑ (121°)  16:44 ↑ (240°)  08:35:12       +4:00
#
#     Astronomical Twilight Unnamed: 6 Nautical Twilight Unnamed: 8  \
# 0                   Start        End             Start        End
# 1                     NaN        NaN               NaN        NaN
# ...
